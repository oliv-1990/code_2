# %%
#libraries

import pandas as pd
import matplotlib.pyplot as plt

# %%
orig_pen_data = pd.read_csv('RAW/penguins.csv')
print(orig_pen_data.columns)
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
print(locals())  # Lists local variables in Python
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', "null_values_zero_df = orig_pen_data.copy()\n\nnull_values_zero_df['bill_depth_mm'] = null_values_zero_df['bill_depth_mm'].fillna(0)\nnull_values_zero_df['bill_length_mm'] = null_values_zero_df['bill_length_mm'].fillna(0)\nnull_values_zero_df['flipper_length_mm'] = null_values_zero_df['flipper_length_mm'].fillna(0)\nnull_values_zero_df['body_mass_g'] = null_values_zero_df['body_mass_g'].fillna(0)\nnull_values_zero_df['sex'] = null_values_zero_df['sex'].fillna('UNK')", "orig_pen_data = pd.read_csv('RAW/penguins.csv')\noprint(original_penguins_data.columns)", '#libraries\n\nimport pandas as pd\nimport matplotlib.pyplot as plt', "orig_pen_data = pd.read_csv('RAW/penguins.csv')\noprint(original_penguins_data.columns)", "orig_pen_data = pd.read_csv('RAW/penguins.csv')\nprint(original_penguins_data.columns)", 'print(locals())  # Lists local variables in Python'], '_oh': {}, '_dh': [WindowsPath('c:/Users/abdul/OneDrive/Desktop/code_2')], 'In': ['', "null_values_zero_df = orig_pen_data.copy()\n\nnull_values_zero_df['bill_depth_mm'] = null_values_zero_df['bill_depth_mm'].fillna(0)\nnull_values_zero_df['bill_length_mm'] = null_values_zero_df['bill_length_mm'].fillna(0)\nnull_values_zero_df['flipper_length_mm'] = null_values_zero_df['flipper_length_mm'].fillna(0)\nnull_values_zero_df['body_mass_g'] = null_values_zero_df['body_mass_g'].fillna(0)\nnull_values_zero_df['sex'] = null_values_zero_df['sex'].fillna('UNK')", "orig_pen_data = pd.read_csv('RAW/penguins.csv')\noprint(original_penguins_data.columns)", '#libraries\n\nimport pandas as pd\nimport matplotlib.pyplot as plt', "orig_pen_data = pd.read_csv('RAW/penguins.csv')\noprint(original_penguins_data.columns)", "orig_pen_data = pd.read_csv('RAW/penguins.csv')\nprint(original_penguins_data.columns)", 'print(locals())  # Lists local variables in Python'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000019D4FD28310>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000019D4FD307D0>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000019D4FD307D0>, 'open': <function open at 0x0000019D4E142480>, '_': '', '__': '', '___': '', '__vsc_ipynb_file__': 'c:\\Users\\abdul\\OneDrive\\Desktop\\code_2\\Untitled-1.ipynb', '_i': "orig_pen_data = pd.read_csv('RAW/penguins.csv')\nprint(original_penguins_data.columns)", '_ii': "orig_pen_data = pd.read_csv('RAW/penguins.csv')\noprint(original_penguins_data.columns)", '_iii': '#libraries\n\nimport pandas as pd\nimport matplotlib.pyplot as plt', '_i1': "null_values_zero_df = orig_pen_data.copy()\n\nnull_values_zero_df['bill_depth_mm'] = null_values_zero_df['bill_depth_mm'].fillna(0)\nnull_values_zero_df['bill_length_mm'] = null_values_zero_df['bill_length_mm'].fillna(0)\nnull_values_zero_df['flipper_length_mm'] = null_values_zero_df['flipper_length_mm'].fillna(0)\nnull_values_zero_df['body_mass_g'] = null_values_zero_df['body_mass_g'].fillna(0)\nnull_values_zero_df['sex'] = null_values_zero_df['sex'].fillna('UNK')", '_i2': "orig_pen_data = pd.read_csv('RAW/penguins.csv')\noprint(original_penguins_data.columns)", '_i3': '#libraries\n\nimport pandas as pd\nimport matplotlib.pyplot as plt', 'pd': <module 'pandas' from 'C:\\Users\\abdul\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\pandas\\__init__.py'>, 'plt': <module 'matplotlib.pyplot' from 'C:\\Users\\abdul\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\matplotlib\\pyplot.py'>, '_i4': "orig_pen_data = pd.read_csv('RAW/penguins.csv')\noprint(original_penguins_data.columns) ...
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns], '_i5': "orig_pen_data = pd.read_csv('RAW/penguins.csv')\nprint(original_penguins_data.columns)", '_i6': 'print(locals())  # Lists local variables in Python'}

# %%
print(orig_pen_data.columns)
print(orig_pen_data.shape)
print(orig_pen_data.dtypes)
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')
# (344, 7)
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
import pandas as pd

orig_pen_data = pd.read_csv("RAW/penguins.csv")

# %%
orig_pen_data['sex'].unique()
# Out:
# array(['MALE', 'FEMALE', nan], dtype=object)

# %%
orig_pen_data['sex'].unique()
nan_count = orig_pen_data.isna().sum()
nan_count
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
nan_values = orig_pen_data[orig_pen_data.isna().any(axis=1)]
nan_values
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 246  Gentoo     Biscoe            44.5           14.3              216.0
# 286  Gentoo     Biscoe            46.2           14.4              214.0
# 324  Gentoo     Biscoe            47.3           13.8              216.0
# 336  Gentoo     Biscoe            44.5           15.7              217.0
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# 11        3700.0  NaN
# 47        2975.0  NaN
# 246       4100.0  NaN
# 286       4650.0  NaN
# 324       4725.0  NaN
# 336       4875.0  NaN
# 339          NaN  NaN

# %%
null_values_zero_df = orig_pen_data.copy()

null_values_zero_df['bill_depth_mm'] = null_values_zero_df['bill_depth_mm'].fillna(0)
null_values_zero_df['bill_length_mm'] = null_values_zero_df['bill_length_mm'].fillna(0)
null_values_zero_df['flipper_length_mm'] = null_values_zero_df['flipper_length_mm'].fillna(0)
null_values_zero_df['body_mass_g'] = null_values_zero_df['body_mass_g'].fillna(0)
null_values_zero_df['sex'] = null_values_zero_df['sex'].fillna('UNK')

null_values_zero_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             0.0            0.0                0.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             0.0            0.0                0.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            0.0     UNK
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          0.0     UNK
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
null_values_average_df = orig_pen_data.copy()

null_values_average_df['bill_length_mm'] = null_values_average_df[['bill_length_mm']].fillna(null_values_average_df[['bill_length_mm']].mean())
null_values_average_df['bill_depth_mm'] = null_values_average_df[['bill_depth_mm']].fillna(null_values_average_df[['bill_depth_mm']].mean())
null_values_average_df['flipper_length_mm'] = null_values_average_df[['flipper_length_mm']].fillna(null_values_average_df[['flipper_length_mm']].mean())
null_values_average_df['body_mass_g'] = null_values_average_df[['body_mass_g']].fillna(null_values_average_df[['body_mass_g']].mean())
null_values_average_df['sex'] = null_values_average_df[['sex']].fillna('UNK')

null_values_average_df.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
penguins_df = null_values_average_df.copy()

gentoo_df = penguins_df[penguins_df['species'] == 'Gentoo']
gentoo_df
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 220  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 221  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 222  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 223  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 224  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..      ...     ...             ...            ...                ...
# 339  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 340  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 341  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 342  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 343  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex
# 220  4500.000000  FEMALE
# 221  5700.000000    MALE
# 222  4450.000000  FEMALE
# 223  5700.000000    MALE
# 224  5400.000000    MALE
# ..           ...     ...
# 339  4201.754386     UNK
# 340  4850.000000  FEMALE
# 341  5750.000000    MALE
# 342  5200.000000  FEMALE
# 343  5400.000000    MALE
#
# [124 rows x 7 columns]

# %%
beefy_gentoo_df = gentoo_df.query("body_mass_g > 5000")
beefy_gentoo_df
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# 227  Gentoo  Biscoe            46.7           15.3              219.0
# 229  Gentoo  Biscoe            46.8           15.4              215.0
# ..      ...     ...             ...            ...                ...
# 335  Gentoo  Biscoe            55.1           16.0              230.0
# 337  Gentoo  Biscoe            48.8           16.2              222.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 221       5700.0    MALE
# 223       5700.0    MALE
# 224       5400.0    MALE
# 227       5200.0    MALE
# 229       5150.0    MALE
# ..           ...     ...
# 335       5850.0    MALE
# 337       6000.0    MALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [61 rows x 7 columns]
